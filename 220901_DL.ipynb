# %% [markdown]
# <a href="https://colab.research.google.com/github/dtype2100/DeepLearning/blob/master/220901_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/taehojo/deeplearning.git
# Out:
# fatal: destination path 'deeplearning' already exists and is not an empty directory.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x = np.array([2, 4, 6, 8, 10, 12, 14])
y = np.array([0, 0, 0, 1, 1, 1, 1])

# %%
model = Sequential()
model.add(Dense(1, input_dim=1, activation='sigmoid'))

# 교차 엔트로피 오차 함수를 이용하기 위하여 'binary_crossentropy'로 설정합니다. 
model.compile(optimizer='sgd' ,loss='binary_crossentropy')

model.fit(x, y, epochs=5000)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2630
# Epoch 2502/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2629
# Epoch 2503/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2629
# Epoch 2504/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2628
# Epoch 2505/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2628
# Epoch 2506/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2627
# Epoch 2507/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2627
# Epoch 2508/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2626
# Epoch 2509/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2626
# Epoch 2510/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2625
# Epoch 2511/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2625
# Epoch 2512/5000
# ...

# %%
plt.scatter(x, y)
plt.plot(x, model.predict(x), 'r')
plt.show()

# %%
hour = 7
prediction = model.predict([hour])
#(hour, prediction * 100))
print("%.f 시간을 공부할 경우, 합격 예상 확률은 %.01f%%입니다" % 
      (hour, prediction * 100))

# %% [markdown]
# # XOR 문제: 직선을 그릴 수 없음 (곡선으로 해결)
# * 해결 1: 다층 퍼셉트론
# * 해결 2: 오차 역전파(back propagation)
#   * 입력층까지 거슬러 올라가면서 수정
# * [논문 참고](http://colah.github.io/posts/2015-09-NN-Types-FP/)
#
# * 다층 퍼셉트론 설계: 입력층과 출력층 사이에 숨업있는 은닉층 생성
# * 순전파(propagation): 기울기 소실 문제 발생
# * 경사하강법: 계산량이 많아서 느림
#   * 확률적 경사하강법(Stochastic Gradiend, SGD): 전체가 아니라, 랜덤하게 일부데이터만 사용하여 더 자주 빠르게 업데이트 가능.
#   * 모맨텀(momentum): 관성의 방향을 고려해 진동과 폭을 줄이는 효과
#   * 네스테로프 모멘텀(NAG): 모멘텀을 이동시킬 방향으로 미리 이동해 불필요한 이동을 줄이는 효과
#   * adam: 정확도, 속도 모두 향상(모멘텀과 RMSProp을 합친 방법)

# %%
model.add(30, input_dim=16, activation='relu')) # 출력값 30, 입력값: input_dim
model.add(Dense(1, activation='sigmoid')) # 출력값: 1

# %% [markdown]
# # 피마 인디언

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sesac/source/Deep_learning/deeplearning/data/pima-indians-diabetes3.csv')

X = df.iloc[:, 0:8] # diabetes 제외 나머지 컬럼
y = df.iloc[:, 8] # diabetes

model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu', name='Dense_1'))
model.add(Dense(8, activation = 'relu', name='Dense_2'))
model.add(Dense(1, activation = 'sigmoid', name='Dense_3'))
model.summary()

# %%
type(X)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history=model.fit(X, y, epochs=100, batch_size=5)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv('/content/deeplearning/data/iris3.csv')

X = df.iloc[:, 0:4]
y = df.iloc[:, 4]

y = pd.get_dummies(y)

model = Sequential()
model.add(Dense(12, input_dim=4, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history=model.fit(X, y, epochs=30, batch_size=5)

# %%
iris1 = [5.3, 2.6, 1, 0.2]
iris2 = [7.3, 2.8, 6.7, 2]
print(model.predict([iris1]))
print(model.predict([iris2]))

# %%
import pandas as pd
df = pd.read_csv('/content/deeplearning/data/sonar3.csv', header=None)
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   0
# 1  0.0052  0.0044   0
# 2  0.0095  0.0078   0
# ...

# %%
df[60].value_counts()
# Out:
# 1    111
# 0     97
# Name: 60, dtype: int64

# %%
# 음파 관련 속성을 X로, 광물의 종류를 y로 저장합니다.
X = df.iloc[:,0:60]
y = df.iloc[:,60]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(24, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(X, y, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 21/21 [==============================] - 1s 3ms/step - loss: 0.6866 - accuracy: 0.5433
# Epoch 2/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6771 - accuracy: 0.5769
# Epoch 3/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.6693 - accuracy: 0.6442
# Epoch 4/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6593 - accuracy: 0.6587
# Epoch 5/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6512 - accuracy: 0.6779
# Epoch 6/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6385 - accuracy: 0.6827
# Epoch 7/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6251 - accuracy: 0.7404
# Epoch 8/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6101 - accuracy: 0.6875
# Epoch 9/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5976 - accuracy: 0.7596
# Epoch 10/200
# ...

# %% [markdown]
# # 과적합
# * 주어진 데이터에만 최적화

# %% [markdown]
# # 홀듯아웃
# * [metrics](https://www.tensorflow.org/api_docs/python/tf/keras/metrics)

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

# %%
X = df.iloc[:,0:60]
y = df.iloc[:,60]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)

model = Sequential()
model.add(Dense(24, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(X, y, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 21/21 [==============================] - 1s 3ms/step - loss: 0.7056 - accuracy: 0.4856
# Epoch 2/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6869 - accuracy: 0.5385
# Epoch 3/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6683 - accuracy: 0.6635
# Epoch 4/200
# 21/21 [==============================] - 0s 4ms/step - loss: 0.6473 - accuracy: 0.6971
# Epoch 5/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6247 - accuracy: 0.7212
# Epoch 6/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6009 - accuracy: 0.7692
# Epoch 7/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5780 - accuracy: 0.7596
# Epoch 8/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5524 - accuracy: 0.7788
# Epoch 9/200
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5248 - accuracy: 0.7788
# Epoch 10/200
# ...

# %%
model.save('my_model.hdf5')

# %%
# 테스트를 위해 조금 전 사용한 모델을 메모리에서 삭제합니다.
del model

# %%
from keras.models import load_model

# %%
# 모델을 새로 불러옵니다.
model = load_model('/content/my_model.hdf5') 

# 불러온 모델을 테스트셋에 적용해 정확도를 구합니다. 
score=model.evaluate(X_test, y_test)
print('Test accuracy:', score[1])
# Out:
# 2/2 [==============================] - 1s 8ms/step - loss: 0.0387 - accuracy: 0.9841
# Test accuracy: 0.9841269850730896

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

import pandas as pd
df = pd.read_csv('/content/deeplearning/data/sonar3.csv', header=None)

X = df.iloc[:,0:60]
y = df.iloc[:,60]
k=5 #몇 겹으로 나눌 것인지를 정합니다. 
kfold = KFold(n_splits=k, shuffle=True)

acc_score = []

def model_fn():
    model = Sequential() 
    model.add(Dense(24, input_dim=60, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    return model

#K겹 교차 검증을 이용해 k번의 학습을 실행합니다. 
for train_index , test_index in kfold.split(X):  
    X_train , X_test = X.iloc[train_index,:], X.iloc[test_index,:]  
    y_train , y_test = y.iloc[train_index], y.iloc[test_index]

    model = model_fn()
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    history=model.fit(X_train, y_train, epochs=200, batch_size=10, verbose=0) 
    
    accuracy = model.evaluate(X_test, y_test)[1]
    print(accuracy)
    acc_score.append(accuracy)  

#k번 실시된 정확도의 평균을 구합니다.
avg_acc_score = sum(acc_score)/k
print('정확도:', acc_score)
print('정확도 평균:', avg_acc_score)
# Out:
# 2/2 [==============================] - 0s 14ms/step - loss: 1.0461 - accuracy: 0.7143
# 0.7142857313156128
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5368 - accuracy: 0.8810
# 0.8809523582458496
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6185 - accuracy: 0.8095
# 0.8095238208770752
# ...

# %% [markdown]
# # practice

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sesac/source/Deep_learning/bmi.csv')
print(df.shape)
df.head(1)
# Out:
# (20000, 3)
#    height  weight label
# 0     186      47  thin

# %%
X = df[['height', 'weight']]
y = df.iloc[:, -1]
y = pd.get_dummies(y)

# %%
y
# Out:
#        fat  normal  thin
# 0        0       0     1
# 1        1       0     0
# 2        1       0     0
# 3        0       1     0
# 4        1       0     0
# ...    ...     ...   ...
# 19995    0       0     1
# 19996    0       0     1
# 19997    1       0     0
# 19998    0       1     0
# 19999    1       0     0
#
# [20000 rows x 3 columns]

# %%
X
# Out:
#        height  weight
# 0         186      47
# 1         143      74
# 2         144      55
# 3         173      60
# 4         170      74
# ...       ...     ...
# 19995     198      67
# 19996     150      41
# 19997     127      42
# 19998     170      65
# 19999     125      54
#
# [20000 rows x 2 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)

model = Sequential()
model.add(Dense(24, input_dim=2, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(3, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history=model.fit(X_train, y_train, epochs=200, batch_size=128)
model.evaluate(X_test, y_test)

accuracy = model.evaluate(X_test, y_test)[1]  # 정확도를 구합니다.
human1 = [178, 57]
human2 = [173, 68]
model.predict([human1]) # thin
model.predict([human2]) # normal
# Out:
# Epoch 1/200
# 110/110 [==============================] - 1s 2ms/step - loss: 4.6660 - accuracy: 0.3691
# Epoch 2/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.8683 - accuracy: 0.5005
# Epoch 3/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.6424 - accuracy: 0.7331
# Epoch 4/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.5541 - accuracy: 0.7621
# Epoch 5/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.5119 - accuracy: 0.7679
# Epoch 6/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4861 - accuracy: 0.7708
# Epoch 7/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4744 - accuracy: 0.7717
# Epoch 8/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4640 - accuracy: 0.7733
# Epoch 9/200
# 110/110 [==============================] - 0s 2ms/step - loss: 0.4554 - accuracy: 0.7751
# Epoch 10/200
# ...
